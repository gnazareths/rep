# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
% matplotlib inline

# %%
test_df = pd.read_csv("~/real_estate/data/v9/test_df.csv")
train_df = pd.read_csv("~/real_estate/data/v9/train_df.csv")
train_df_adasyn = pd.read_csv("~/real_estate/data/v9/train_df_adasyn.csv")
train_df_smote_1 = pd.read_csv("~/real_estate/data/v9/train_df_smote_ratio.csv")

features = train_df.columns[:-2]

X_test = test_df[features].values
X_train = train_df[features].values
X_train_adasyn = train_df_adasyn[features].values
X_train_smote_1 = train_df_smote_1[features].values

y_test = test_df["target"].values
y_train = train_df["target"].values
y_train_adasyn = train_df_adasyn["target"].values
y_train_smote_1 = train_df_smote_1["target"].values

# %% [markdown]
# ### Train Linear Regressions

# %%
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
y_test_hat_1 = model_1.predict(X_test)
y_train_hat_1 = model_1.predict(X_train)
print("R^2 train: ", np.square(np.corrcoef(y_train, y_train_hat_1)[0,1]))
print("R^2 test: ", np.square(np.corrcoef(y_test, y_test_hat_1)[0,1]))
# Out:
# R^2 train:  0.46549617133400173
# R^2 test:  0.3111035737187824

# %% [markdown]
# ### Plot Results

# %%
plt.scatter(y_train, y_train_hat_1)
plt.title("Labels vs Predictions (In-Sample)")
plt.ylabel("Predictions")
plt.xlabel("Labels")
plt.axvline(x=0.25, color="red", linestyle='--')
plt.axhline(y=0.25, color="r", linestyle='--')
plt.show()

plt.scatter(y_test, y_test_hat_1)
plt.title("Labels vs Predictions (Out-of-Sample)")
plt.ylabel("Predictions")
plt.xlabel("Labels")
plt.axvline(x=0.25, color="red", linestyle='--')
plt.axhline(y=0.25, color="r", linestyle='--')
plt.show()

# %% [markdown]
# ### Get Coefficients

# %%
model = sm.OLS(y_train, X_train)
model = model.fit()

coefficients = model.params
standard_errors = model.HC0_se

regression_table = pd.DataFrame({"coefficients":coefficients, 
                                 "standard_errors":standard_errors}, index=features)

# %%
regression_table
# Out:
#                                        coefficients  standard_errors
# 90_day_treasury_bill_rate                  0.016387         0.007174
# mean_adjusted_income_lag_log              -0.137513         0.026651
# mean_adjusted_income_with_dep_lag_log      0.126277         0.025683
# mean_fixed_mortgage_rate                   0.008050         0.005548
# mean_hourly_earnings_adj                  -0.053470         0.092740
# mean_mortgage_interest_hh_lag_log          0.101090         0.009474
# mean_real_estate_taxes_hh_lag_log         -0.074453         0.008188
# median_sqft_value_log                     -0.008720         0.018575
# month                                     -0.034754         0.016078
# people_count_lag_log                       0.021281         0.003564
# percent_decreasing                         0.235265         0.018615
# percent_increasing                         0.278734         0.017190
# total_nonfarm_payroll                      0.267666         0.089348
# year                                      -0.184996         0.088298
# zhvi_condo_log                            -0.134016         0.006762
# zhvi_singlefam_log                         0.046389         0.020304
# zri_sqft_value_log                         0.103027         0.011577
# adult_count_lag_mo                         0.752754         0.154803
# mean_mortgage_interest_hh_lag_mo           0.005196         0.008416
# mean_fixed_mortgage_rate_mo                0.000423         0.003911
# percent_decreasing_mo                     -0.030256         0.016327
# zhvi_singlefam_mo                          0.075753         0.011282
# mean_adjusted_income_with_dep_lag_mo      -4.391750         0.746849
# zri_sqft_value_mo                         -0.017000         0.014635
# percent_increasing_mo                      0.098404         0.021250
# 90_day_treasury_bill_rate_mo              -0.014032         0.004011
# total_nonfarm_payroll_mo                   0.001403         0.002796
# mean_adjusted_income_lag_mo                4.015650         0.703950
# mean_real_estate_taxes_hh_lag_mo          -0.014197         0.020463
# mean_hourly_earnings_adj_mo                0.007620         0.003417
# people_count_lag_mo                       -0.939902         0.177798
# zhvi_condo_mo                              0.198477         0.010642
# median_sqft_value_mo                       0.038212         0.008664
# percent_decreasing_yr                      0.006297         0.006277
# percent_increasing_yr                      0.264223         0.014741
# adult_count_lag_yr                         0.074889         0.073658
# mean_fixed_mortgage_rate_yr               -0.050383         0.006078
# mean_adjusted_income_lag_yr               -0.349779         0.345814
# zhvi_singlefam_yr                         -0.021618         0.015016
# zri_sqft_value_yr                         -0.028814         0.009476
# zhvi_condo_yr                             -0.201075         0.008608
# mean_mortgage_interest_hh_lag_yr          -0.085960         0.011449
# total_nonfarm_payroll_yr                  -0.025169         0.007418
# people_count_lag_yr                        0.058724         0.131121
# mean_hourly_earnings_adj_yr               -0.018259         0.007388
# median_sqft_value_yr                       0.118451         0.017480
# 90_day_treasury_bill_rate_yr               0.012784         0.005441
# mean_real_estate_taxes_hh_lag_yr          -0.050535         0.010077
# mean_adjusted_income_with_dep_lag_yr       0.401989         0.381900
