# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt
% matplotlib inline

# %%
test_df = pd.read_csv("~/real_estate/data/v11/test_df.csv")
train_df = pd.read_csv("~/real_estate/data/v11/train_df.csv")
#train_df_adasyn = pd.read_csv("~/real_estate/data/v9/train_df_adasyn.csv")
#train_df_smote = pd.read_csv("~/real_estate/data/v9/train_df_smote_ratio.csv")

features = train_df.columns[:-2]

X_test = test_df[features].values
X_train = train_df[features].values
#X_train_adasyn = train_df_adasyn[features].values
#X_train_smote = train_df_smote[features].values

y_test = test_df["target"].values
y_train = train_df["target"].values
#y_train_adasyn = train_df_adasyn["target"].values
#y_train_smote = train_df_smote["target"].values

# %% [markdown]
# ### Train Linear Regressions

# %%
model_1 = LinearRegression()
model_1.fit(X_train, y_train)
y_test_hat_1 = model_1.predict(X_test)
y_train_hat_1 = model_1.predict(X_train)
print("R^2 train: ", np.square(np.corrcoef(y_train, y_train_hat_1)[0,1]))
print("R^2 test: ", np.square(np.corrcoef(y_test, y_test_hat_1)[0,1]))
# Out:
# R^2 train:  0.381386633407205
# R^2 test:  0.28239709454440454

# %% [markdown]
# ### Plot Results

# %%
plt.scatter(y_train, y_train_hat_1)
plt.title("Labels vs Predictions (In-Sample)")
plt.ylabel("Predictions")
plt.xlabel("Labels")
plt.axvline(x=0.25, color="red", linestyle='--')
plt.axhline(y=0.25, color="r", linestyle='--')
plt.show()

plt.scatter(y_test, y_test_hat_1)
plt.title("Labels vs Predictions (Out-of-Sample)")
plt.ylabel("Predictions")
plt.xlabel("Labels")
plt.axvline(x=0.25, color="red", linestyle='--')
plt.axhline(y=0.25, color="r", linestyle='--')
plt.show()

# %%
predictive_df = pd.DataFrame({"label": y_test, "pred": y_test_hat_1})
predictive_df = predictive_df.sort_values(by=["pred"], ascending=False)

predictive_df_25 = predictive_df.loc[predictive_df["pred"] >= .25]
top_10_predictions = predictive_df.head(n=10)
top_25_predictions = predictive_df.head(n=25)

mean_return_over_25 = np.mean(predictive_df_25["label"].values)
mean_return_top_10_predictions = np.mean(top_10_predictions["label"].values)
mean_return_top_25_predictions = np.mean(top_25_predictions["label"].values)

print("Mean return for predictions above 25%: ", mean_return_over_25)
print("Mean return for top 10 predictions: ", mean_return_top_10_predictions)
print("Mean return for top 25 predictions: ", mean_return_top_25_predictions)
# Out:
# Mean return for predictions above 25%:  nan
# Mean return for top 10 predictions:  0.2318467453685055
# Mean return for top 25 predictions:  0.23922439540348114
# /home/gnazareths/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/gnazareths/.local/lib/python3.5/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ### Get Coefficients

# %%
model = sm.OLS(y_train, X_train)
model = model.fit()

coefficients = model.params
standard_errors = model.HC0_se

regression_table = pd.DataFrame({"coefficients":coefficients, 
                                 "standard_errors":standard_errors,
                                 "t-statistics":coefficients/standard_errors}, index=features)

# %%
regression_table
# Out:
#                                        coefficients  standard_errors  \
# year                                  -5.970321e-01     2.653488e-02
# month                                 -1.078087e-01     4.833364e-03
# 90_day_treasury_bill_rate              1.891847e-02     2.460767e-03
# mean_adjusted_income_lag_log           1.743602e-01     1.159168e-02
# mean_adjusted_income_with_dep_lag_log -2.155613e-01     1.111390e-02
# mean_fixed_mortgage_rate              -2.726805e-02     2.272056e-03
# mean_hourly_earnings_adj               1.389989e+10     1.646112e+10
# mean_mortgage_interest_hh_lag_log      6.160504e-02     3.391703e-03
# mean_real_estate_taxes_hh_lag_log     -6.528189e-02     4.221265e-03
# median_sqft_value_log                  5.398375e-02     6.939891e-03
# people_count_lag_log                  -1.661653e-03     2.607869e-03
# percent_decreasing                     5.426278e-02     5.216864e-03
# percent_increasing                     1.447867e-01     4.956505e-03
# total_nonfarm_payroll                  6.300270e-01     3.111786e-02
# zhvi_condo_log                        -1.917832e-01     3.482896e-03
# zhvi_singlefam_log                     1.026113e-01     6.219481e-03
# zri_sqft_value_log                     4.873745e-02     3.791878e-03
# business_count_cbp_lag_log             1.002692e-02     2.773684e-03
# business_500_count_cbp_lag            -3.220759e-04     2.667480e-03
# bar_count_cbp_lag                     -6.226811e-03     2.391423e-03
# mean_county_zhvi_condo_log             8.078194e-02     9.752220e-03
# median_county_zhvi_condo_log          -2.597542e-02     8.912905e-03
# mean_county_sqft_value_log            -1.131511e-01     1.227602e-02
# median_county_sqft_value_log           8.088478e-02     1.170917e-02
# mean_county_hourly_earnings_adj       -1.389989e+10     1.646112e+10
# mean_fixed_mortgage_rate_mo            3.021461e-03     1.437505e-03
# percent_decreasing_mo                 -1.771228e-01     2.588815e-02
# zhvi_singlefam_mo                      4.772754e-02     6.298909e-03
# zri_sqft_value_mo                      5.963811e-03     5.403190e-03
# percent_increasing_mo                  3.466598e-02     9.430261e-03
# ...                                             ...              ...
# mean_adjusted_income_lag_yr            8.847309e-01     1.547769e-01
# zhvi_singlefam_yr                     -4.388807e-03     6.177468e-03
# zri_sqft_value_yr                      3.255929e-02     4.785437e-03
# zhvi_condo_yr                         -2.504305e-01     4.506644e-03
# mean_mortgage_interest_hh_lag_yr      -4.273628e-01     1.574409e-02
# total_nonfarm_payroll_yr              -1.796365e-02     2.645258e-03
# people_count_lag_yr                   -4.094874e-01     7.120892e-02
# mean_hourly_earnings_adj_yr            8.168302e+08     9.673416e+08
# median_sqft_value_yr                   1.082138e-01     6.355856e-03
# 90_day_treasury_bill_rate_yr           1.546599e-02     1.953440e-03
# mean_real_estate_taxes_hh_lag_yr      -1.154217e-01     2.501873e-02
# mean_adjusted_income_with_dep_lag_yr  -6.915794e-01     1.319120e-01
# business_count_cbp_lag_yr              7.127702e-02     1.002470e-02
# employment_count_cbp_lag_yr           -2.666059e-03     3.460079e-03
# business_100_count_cbp_lag_yr         -1.701215e-03     2.753367e-03
# restaurant_count_cbp_lag_yr           -2.172685e-02     1.272338e-03
# business_500_count_cbp_lag_yr          3.283795e-03     1.161729e-03
# bar_count_cbp_lag_yr                  -1.086655e-03     1.005507e-03
# mean_county_zhvi_condo_yr              1.985422e-01     1.642937e-02
# mean_county_zhvi_condo_mo              3.970881e-02     1.105324e-02
# median_county_zhvi_condo_yr           -1.958681e-02     1.601498e-02
# median_county_zhvi_condo_mo            7.292606e-02     1.208677e-02
# mean_county_sqft_value_mo              1.018716e-01     1.274508e-02
# median_county_sqft_value_mo           -3.514313e-02     9.599845e-03
# mean_county_sqft_value_yr              9.815517e-02     1.789796e-02
# median_county_sqft_value_yr           -1.799452e-01     1.862499e-02
# mean_county_hourly_earnings_adj_mo    -2.604376e+06     3.084266e+06
# median_county_hourly_earnings_adj_mo   1.618201e+06     1.916376e+06
# mean_county_hourly_earnings_adj_yr    -1.628047e+09     1.928035e+09
# median_county_hourly_earnings_adj_yr   8.112163e+08     9.606933e+08
#
#                                        t-statistics
# year                                     -22.499896
# month                                    -22.305114
# 90_day_treasury_bill_rate                  7.688038
# mean_adjusted_income_lag_log              15.041849
# mean_adjusted_income_with_dep_lag_log    -19.395656
# mean_fixed_mortgage_rate                 -12.001484
# mean_hourly_earnings_adj                   0.844407
# mean_mortgage_interest_hh_lag_log         18.163452
# mean_real_estate_taxes_hh_lag_log        -15.465008
# median_sqft_value_log                      7.778761
# people_count_lag_log                      -0.637169
# percent_decreasing                        10.401418
# percent_increasing                        29.211442
# total_nonfarm_payroll                     20.246478
# zhvi_condo_log                           -55.064294
# zhvi_singlefam_log                        16.498370
# zri_sqft_value_log                        12.853116
# business_count_cbp_lag_log                 3.615018
# business_500_count_cbp_lag                -0.120742
# bar_count_cbp_lag                         -2.603810
# mean_county_zhvi_condo_log                 8.283441
# median_county_zhvi_condo_log              -2.914360
# mean_county_sqft_value_log                -9.217252
# median_county_sqft_value_log               6.907815
# mean_county_hourly_earnings_adj           -0.844407
# mean_fixed_mortgage_rate_mo                2.101878
# percent_decreasing_mo                     -6.841846
# zhvi_singlefam_mo                          7.577111
# zri_sqft_value_mo                          1.103757
# percent_increasing_mo                      3.676037
# ...                                             ...
# mean_adjusted_income_lag_yr                5.716169
# zhvi_singlefam_yr                         -0.710454
# zri_sqft_value_yr                          6.803828
# zhvi_condo_yr                            -55.569173
# mean_mortgage_interest_hh_lag_yr         -27.144337
# total_nonfarm_payroll_yr                  -6.790889
# people_count_lag_yr                       -5.750506
# mean_hourly_earnings_adj_yr                0.844407
# median_sqft_value_yr                      17.025834
# 90_day_treasury_bill_rate_yr               7.917310
# mean_real_estate_taxes_hh_lag_yr          -4.613414
# mean_adjusted_income_with_dep_lag_yr      -5.242732
# business_count_cbp_lag_yr                  7.110142
# employment_count_cbp_lag_yr               -0.770520
# business_100_count_cbp_lag_yr             -0.617867
# restaurant_count_cbp_lag_yr              -17.076327
# business_500_count_cbp_lag_yr              2.826644
# bar_count_cbp_lag_yr                      -1.080704
# mean_county_zhvi_condo_yr                 12.084593
# mean_county_zhvi_condo_mo                  3.592505
# median_county_zhvi_condo_yr               -1.223031
# median_county_zhvi_condo_mo                6.033545
# mean_county_sqft_value_mo                  7.993008
# median_county_sqft_value_mo               -3.660802
# mean_county_sqft_value_yr                  5.484153
# median_county_sqft_value_yr               -9.661490
# mean_county_hourly_earnings_adj_mo        -0.844407
# median_county_hourly_earnings_adj_mo       0.844407
# mean_county_hourly_earnings_adj_yr        -0.844407
# median_county_hourly_earnings_adj_yr       0.844407
#
# [69 rows x 3 columns]
